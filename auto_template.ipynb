# %%
import pandas as pd
import numpy as np

# %%
vk_spec = pd.read_excel("auto_spec_db_trial_volkswagen (2).xlsx", sheet_name="V2")

# %%
vk_spec1 = vk_spec[['OEM', 'Brand', 'Vehicle classification', 'Model family']]

# %%
vk_spec1 = vk_spec1.drop_duplicates()

# %%
vk_spec1 = vk_spec1.reset_index(drop=True)

# %%
vk_spec1 = vk_spec1.sort_values(by=['Vehicle classification', 'Model family'])

# %%
vk_spec1
# Out:
#                  OEM       Brand Vehicle classification  \
# 9   Volkswagen Group  Volkswagen                    Car
# 2   Volkswagen Group  Volkswagen                    Car
# 0   Volkswagen Group  Volkswagen                    Car
# 4   Volkswagen Group  Volkswagen                    Car
# 6   Volkswagen Group  Volkswagen                    Car
# 8   Volkswagen Group  Volkswagen                    Car
# 1   Volkswagen Group  Volkswagen                    Car
# 3   Volkswagen Group  Volkswagen                    Car
# 7   Volkswagen Group  Volkswagen                    Car
# 16  Volkswagen Group  Volkswagen                    MPV
# 14  Volkswagen Group  Volkswagen                    MPV
# 15  Volkswagen Group  Volkswagen                    MPV
# 17  Volkswagen Group  Volkswagen                 Pickup
# 5   Volkswagen Group  Volkswagen          SUV/Crossover
# 18  Volkswagen Group  Volkswagen          SUV/Crossover
# 10  Volkswagen Group  Volkswagen          SUV/Crossover
# 19  Volkswagen Group  Volkswagen          SUV/Crossover
# 12  Volkswagen Group  Volkswagen          SUV/Crossover
# 11  Volkswagen Group  Volkswagen          SUV/Crossover
# 13  Volkswagen Group  Volkswagen          SUV/Crossover
#
#                        Model family
# 9                         Arteon/CC
# 2               Bora/Lavida/Sagitar
# 0                        Golf/Jetta
# 4                              ID.3
# 6                    Passat/Magotan
# 8                           Phideon
# 1                              Polo
# 3              Virtus/Vento/Santana
# 7              Volkswage Car Others
# 16                          ID.Buzz
# 14                    Touran/Sharan
# 15                          Viloran
# 17                           Amarok
# 5                         ID.4/ID.5
# 18                             ID.6
# 10      T-Cross/Tacqua/Taigun/Taigo
# 19                       Taos/Tharu
# 12  Teramont/Atlas/Talagon/Tavendor
# 11                    Tiguan/Tayron
# 13                          Touareg

# %%
gp = list(vk_spec1.groupby(['Vehicle classification']))
row_list = []

for ind, row in gp:
    n = row.shape[1]
    v_line = pd.DataFrame([[np.NAN]*n], columns=row.columns)
    row_nan = pd.concat([row, v_line], axis=0)
    row_list.append(row_nan)
step2_vk_temp = pd.concat(row_list)

# %%
step2_vk_temp = step2_vk_temp.reset_index(drop=True)

# %%
step2_vk_temp
# Out:
#                  OEM       Brand Vehicle classification  \
# 0   Volkswagen Group  Volkswagen                    Car
# 1   Volkswagen Group  Volkswagen                    Car
# 2   Volkswagen Group  Volkswagen                    Car
# 3   Volkswagen Group  Volkswagen                    Car
# 4   Volkswagen Group  Volkswagen                    Car
# 5   Volkswagen Group  Volkswagen                    Car
# 6   Volkswagen Group  Volkswagen                    Car
# 7   Volkswagen Group  Volkswagen                    Car
# 8   Volkswagen Group  Volkswagen                    Car
# 9                NaN         NaN                    NaN
# 10  Volkswagen Group  Volkswagen                    MPV
# 11  Volkswagen Group  Volkswagen                    MPV
# 12  Volkswagen Group  Volkswagen                    MPV
# 13               NaN         NaN                    NaN
# 14  Volkswagen Group  Volkswagen                 Pickup
# 15               NaN         NaN                    NaN
# 16  Volkswagen Group  Volkswagen          SUV/Crossover
# 17  Volkswagen Group  Volkswagen          SUV/Crossover
# 18  Volkswagen Group  Volkswagen          SUV/Crossover
# 19  Volkswagen Group  Volkswagen          SUV/Crossover
# 20  Volkswagen Group  Volkswagen          SUV/Crossover
# 21  Volkswagen Group  Volkswagen          SUV/Crossover
# 22  Volkswagen Group  Volkswagen          SUV/Crossover
# 23               NaN         NaN                    NaN
#
#                        Model family
# 0                         Arteon/CC
# 1               Bora/Lavida/Sagitar
# 2                        Golf/Jetta
# 3                              ID.3
# 4                    Passat/Magotan
# 5                           Phideon
# 6                              Polo
# 7              Virtus/Vento/Santana
# 8              Volkswage Car Others
# 9                               NaN
# 10                          ID.Buzz
# 11                    Touran/Sharan
# 12                          Viloran
# 13                              NaN
# 14                           Amarok
# 15                              NaN
# 16                        ID.4/ID.5
# 17                             ID.6
# 18      T-Cross/Tacqua/Taigun/Taigo
# 19                       Taos/Tharu
# 20  Teramont/Atlas/Talagon/Tavendor
# 21                    Tiguan/Tayron
# 22                          Touareg
# 23                              NaN

# %%
cols =["Australia", "India", "South East Asia", "Japan", "Rest of Asia Pacific", "South Korea", "People's Republic of China (mainland)", "Rest of Greater China", "Rest of Central & Eastern Europe",
                "Rest of Middle East", "France", "Germany", "UK", "Rest of Latin America", "Canada", "United States", "space1", "space2", "Australia-r", "India-r", "South East Asia-r", "Japan-r", "Rest of Asia Pacific-r", "South Korea-r", "People's Republic of China (mainland)-r", "Rest of Greater China-r", "Rest of Central & Eastern Europe-r",
                "Rest of Middle East-r", "France-r", "Germany-r", "UK-r", "Rest of Latin America-r", "Canada-r", "United States-r"]

# %%
df2 = pd.DataFrame(columns=cols)

# %%
df2
# Out:
# Empty DataFrame
# Columns: [Australia, India, South East Asia, Japan, Rest of Asia Pacific, South Korea, People's Republic of China (mainland), Rest of Greater China, Rest of Central & Eastern Europe, Rest of Middle East, France, Germany, UK, Rest of Latin America, Canada, United States, space1, space2, Australia-r, India-r, South East Asia-r, Japan-r, Rest of Asia Pacific-r, South Korea-r, People's Republic of China (mainland)-r, Rest of Greater China-r, Rest of Central & Eastern Europe-r, Rest of Middle East-r, France-r, Germany-r, UK-r, Rest of Latin America-r, Canada-r, United States-r]
# Index: []
#
# [0 rows x 34 columns]

# %%
step2_vk_temp = pd.concat([step2_vk_temp, df2], axis=1)

# %%
step2_vk_temp
# Out:
#                  OEM       Brand Vehicle classification  \
# 0   Volkswagen Group  Volkswagen                    Car
# 1   Volkswagen Group  Volkswagen                    Car
# 2   Volkswagen Group  Volkswagen                    Car
# 3   Volkswagen Group  Volkswagen                    Car
# 4   Volkswagen Group  Volkswagen                    Car
# 5   Volkswagen Group  Volkswagen                    Car
# 6   Volkswagen Group  Volkswagen                    Car
# 7   Volkswagen Group  Volkswagen                    Car
# 8   Volkswagen Group  Volkswagen                    Car
# 9                NaN         NaN                    NaN
# 10  Volkswagen Group  Volkswagen                    MPV
# 11  Volkswagen Group  Volkswagen                    MPV
# 12  Volkswagen Group  Volkswagen                    MPV
# 13               NaN         NaN                    NaN
# 14  Volkswagen Group  Volkswagen                 Pickup
# 15               NaN         NaN                    NaN
# 16  Volkswagen Group  Volkswagen          SUV/Crossover
# 17  Volkswagen Group  Volkswagen          SUV/Crossover
# 18  Volkswagen Group  Volkswagen          SUV/Crossover
# 19  Volkswagen Group  Volkswagen          SUV/Crossover
# 20  Volkswagen Group  Volkswagen          SUV/Crossover
# 21  Volkswagen Group  Volkswagen          SUV/Crossover
# 22  Volkswagen Group  Volkswagen          SUV/Crossover
# 23               NaN         NaN                    NaN
#
#                        Model family Australia India South East Asia Japan  \
# 0                         Arteon/CC       NaN   NaN             NaN   NaN
# 1               Bora/Lavida/Sagitar       NaN   NaN             NaN   NaN
# 2                        Golf/Jetta       NaN   NaN             NaN   NaN
# 3                              ID.3       NaN   NaN             NaN   NaN
# 4                    Passat/Magotan       NaN   NaN             NaN   NaN
# 5                           Phideon       NaN   NaN             NaN   NaN
# 6                              Polo       NaN   NaN             NaN   NaN
# 7              Virtus/Vento/Santana       NaN   NaN             NaN   NaN
# 8              Volkswage Car Others       NaN   NaN             NaN   NaN
# 9                               NaN       NaN   NaN             NaN   NaN
# 10                          ID.Buzz       NaN   NaN             NaN   NaN
# 11                    Touran/Sharan       NaN   NaN             NaN   NaN
# 12                          Viloran       NaN   NaN             NaN   NaN
# 13                              NaN       NaN   NaN             NaN   NaN
# 14                           Amarok       NaN   NaN             NaN   NaN
# 15                              NaN       NaN   NaN             NaN   NaN
# 16                        ID.4/ID.5       NaN   NaN             NaN   NaN
# 17                             ID.6       NaN   NaN             NaN   NaN
# 18      T-Cross/Tacqua/Taigun/Taigo       NaN   NaN             NaN   NaN
# 19                       Taos/Tharu       NaN   NaN             NaN   NaN
# 20  Teramont/Atlas/Talagon/Tavendor       NaN   NaN             NaN   NaN
# 21                    Tiguan/Tayron       NaN   NaN             NaN   NaN
# 22                          Touareg       NaN   NaN             NaN   NaN
# 23                              NaN       NaN   NaN             NaN   NaN
#
#    Rest of Asia Pacific South Korea  ...  \
# 0                   NaN         NaN  ...
# 1                   NaN         NaN  ...
# 2                   NaN         NaN  ...
# 3                   NaN         NaN  ...
# 4                   NaN         NaN  ...
# 5                   NaN         NaN  ...
# 6                   NaN         NaN  ...
# 7                   NaN         NaN  ...
# 8                   NaN         NaN  ...
# 9                   NaN         NaN  ...
# 10                  NaN         NaN  ...
# 11                  NaN         NaN  ...
# 12                  NaN         NaN  ...
# 13                  NaN         NaN  ...
# 14                  NaN         NaN  ...
# 15                  NaN         NaN  ...
# 16                  NaN         NaN  ...
# 20       NaN  NaN                     NaN      NaN             NaN
# 21       NaN  NaN                     NaN      NaN             NaN
# 22       NaN  NaN                     NaN      NaN             NaN
# 23       NaN  NaN                     NaN      NaN             NaN
#
# [24 rows x 38 columns]

# %%
# colA = ["OEM", "Brand", "Vehicle classification", "Model family", "Australia", "India", "South East Asia", "Japan", "Rest of Asia Pacific", "South Korea", "People's Republic of China (mainland)", "Rest of Greater China", "Rest of Central & Eastern Europe",
#                 "Rest of Middle East", "France", "Germany", "UK", "Rest of Latin America", "Canada", "United States", " ", " ", "Australia-r", "India-r", "South East Asia-r", "Japan-r", "Rest of Asia Pacific-r", "South Korea-r", "People's Republic of China (mainland)-r", "Rest of Greater China-r", "Rest of Central & Eastern Europe-r",
#                 "Rest of Middle East-r", "France-r", "Germany-r", "UK-r", "Rest of Latin America-r", "Canada-r", "United States-r"]

# %%
all_row = ['ALL', 'ALL', 'ALL', 'ALL']
ALL_df = pd.DataFrame(data = [all_row], columns= ["OEM", "Brand", "Vehicle classification", "Model family"])

for c in cols:
    ALL_df[c] = 0

ALL_df
# Out:
#    OEM Brand Vehicle classification Model family  Australia  India  \
# 0  ALL   ALL                    ALL          ALL          0      0
#
#    South East Asia  Japan  Rest of Asia Pacific  South Korea  ...  \
# 0                0      0                     0            0  ...
#
#    People's Republic of China (mainland)-r  Rest of Greater China-r  \
# 0                                        0                        0
#
#    Rest of Central & Eastern Europe-r  Rest of Middle East-r  France-r  \
# 0                                   0                      0         0
#
#    Germany-r  UK-r  Rest of Latin America-r  Canada-r  United States-r
# 0          0     0                        0         0                0
#
# [1 rows x 38 columns]

# %%
nan_row = pd.DataFrame([[np.NAN]*38], columns = ALL_df.columns)

# %%
gp = list(step2_vk_temp.groupby(['Vehicle classification']))
row_list = []

for ind, row in gp:
    for c in cols:
        ALL_df[c] = 0
        res = pd.concat([ALL_df, row, nan_row], axis=0)
    row_list.append(res)

# %%
fin = pd.concat(row_list).reset_index(drop=True)

# %%
fin
# Out:
#                  OEM       Brand Vehicle classification  \
# 0                ALL         ALL                    ALL
# 1   Volkswagen Group  Volkswagen                    Car
# 2   Volkswagen Group  Volkswagen                    Car
# 3   Volkswagen Group  Volkswagen                    Car
# 4   Volkswagen Group  Volkswagen                    Car
# 5   Volkswagen Group  Volkswagen                    Car
# 6   Volkswagen Group  Volkswagen                    Car
# 7   Volkswagen Group  Volkswagen                    Car
# 8   Volkswagen Group  Volkswagen                    Car
# 9   Volkswagen Group  Volkswagen                    Car
# 10               NaN         NaN                    NaN
# 11               ALL         ALL                    ALL
# 12  Volkswagen Group  Volkswagen                    MPV
# 13  Volkswagen Group  Volkswagen                    MPV
# 14  Volkswagen Group  Volkswagen                    MPV
# 15               NaN         NaN                    NaN
# 16               ALL         ALL                    ALL
# 17  Volkswagen Group  Volkswagen                 Pickup
# 18               NaN         NaN                    NaN
# 19               ALL         ALL                    ALL
# 20  Volkswagen Group  Volkswagen          SUV/Crossover
# 21  Volkswagen Group  Volkswagen          SUV/Crossover
# 22  Volkswagen Group  Volkswagen          SUV/Crossover
# 23  Volkswagen Group  Volkswagen          SUV/Crossover
# 24  Volkswagen Group  Volkswagen          SUV/Crossover
# 25  Volkswagen Group  Volkswagen          SUV/Crossover
# 26  Volkswagen Group  Volkswagen          SUV/Crossover
# 27               NaN         NaN                    NaN
#
#                        Model family Australia India South East Asia Japan  \
# 0                               ALL         0     0               0     0
# 1                         Arteon/CC       NaN   NaN             NaN   NaN
# 2               Bora/Lavida/Sagitar       NaN   NaN             NaN   NaN
# 3                        Golf/Jetta       NaN   NaN             NaN   NaN
# 4                              ID.3       NaN   NaN             NaN   NaN
# 5                    Passat/Magotan       NaN   NaN             NaN   NaN
# 6                           Phideon       NaN   NaN             NaN   NaN
# 7                              Polo       NaN   NaN             NaN   NaN
# 8              Virtus/Vento/Santana       NaN   NaN             NaN   NaN
# 9              Volkswage Car Others       NaN   NaN             NaN   NaN
# 10                              NaN       NaN   NaN             NaN   NaN
# 11                              ALL         0     0               0     0
# 12                          ID.Buzz       NaN   NaN             NaN   NaN
# 13                    Touran/Sharan       NaN   NaN             NaN   NaN
# 14                          Viloran       NaN   NaN             NaN   NaN
# 15                              NaN       NaN   NaN             NaN   NaN
# 16                              ALL         0     0               0     0
# 17                           Amarok       NaN   NaN             NaN   NaN
# 18                              NaN       NaN   NaN             NaN   NaN
# 19                              ALL         0     0               0     0
# 20                        ID.4/ID.5       NaN   NaN             NaN   NaN
# 21                             ID.6       NaN   NaN             NaN   NaN
# 22      T-Cross/Tacqua/Taigun/Taigo       NaN   NaN             NaN   NaN
# 23                       Taos/Tharu       NaN   NaN             NaN   NaN
# 24  Teramont/Atlas/Talagon/Tavendor       NaN   NaN             NaN   NaN
# 25                    Tiguan/Tayron       NaN   NaN             NaN   NaN
# 26                          Touareg       NaN   NaN             NaN   NaN
# 27                              NaN       NaN   NaN             NaN   NaN
#
#    Rest of Asia Pacific South Korea  ...  \
# 0                     0           0  ...
# 1                   NaN         NaN  ...
# 2                   NaN         NaN  ...
# 3                   NaN         NaN  ...
# 4                   NaN         NaN  ...
# 5                   NaN         NaN  ...
# 6                   NaN         NaN  ...
# 7                   NaN         NaN  ...
# 8                   NaN         NaN  ...
# 9                   NaN         NaN  ...
# 10                  NaN         NaN  ...
# 11                    0           0  ...
# 12                  NaN         NaN  ...
# 13                  NaN         NaN  ...
# 14                  NaN         NaN  ...
# 15                  NaN         NaN  ...
# 16                    0           0  ...
# 17                  NaN         NaN  ...
# 18                  NaN         NaN  ...
# 19                    0           0  ...
# 20                  NaN         NaN  ...
# 21                  NaN         NaN  ...
# 22                  NaN         NaN  ...
# 23                  NaN         NaN  ...
# 24                  NaN         NaN  ...
# 25                  NaN         NaN  ...
# 26                  NaN         NaN  ...
# 27                  NaN         NaN  ...
#
#    People's Republic of China (mainland)-r Rest of Greater China-r  \
# 0                                        0                       0
# 1                                      NaN                     NaN
ip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.1.0-py3-none-any.whl (152 kB)
#      ------------------------------------ 152.7/152.7 kB 912.9 kB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.1.0

# %%
from pandas import ExcelWriter, read_excel
 
with pd.ExcelWriter('1234.xlsx', engine='xlsxwriter') as writer:
    fin.to_excel(writer, sheet_name='Sheet1')
    formatObj = writer.book.add_format({'num_format': '0.00%'})
    writer.book.sheetnames['Sheet1'].set_column('X:AN', cell_format=formatObj)
    workbook = writer.book
    worksheet = writer.sheets['Sheet1']
    
    header_no_color = workbook.add_format(
    {
        "bold": True,
        "text_wrap": True,
        "valign": "top",
        "fg_color": "#FFFFFF",
        "border": 1,
    }
)
    colors = ['#CD5C5C', '#F08080', '#FA8072', '#E9967A', 
          '#FFA07A', '#DC143C', '#FF0000', '#B22222', 
          '#8B0000', '#3CB371', '#2E8B57', '#228B22', 
          '#008000', '#006400', '#9ACD32', '#6B8E23',
          '#808000', '#556B2F', '#66CDAA', '#8FBC8B',
          '#20B2AA', '#008B8B', '#008080', '#ADD8E6', '#87CEEB',
          '#87CEFA', '#00BFFF', '#1E90FF', '#6495ED', '#7B68EE',
          '#4169E1', '#0000FF', '#E6E6FA', '#D8BFD8']
    for col_num, value in enumerate(fin.columns.values):
    
        if value in fin.columns.values[4:]:

            # print(col_num)    
            header_format = workbook.add_format(
                {
                 "bold": True,
                 "text_wrap": True,
                 "valign": "top",
                 "fg_color": colors[col_num - 10],
                 "border": 1,
                 }
                )

            worksheet.write(0, col_num + 1, value, header_format)

        else:
            worksheet.write(0, col_num + 1, value, header_no_color)

    
writer.close()
# Out:
# C:\Users\DanHan\anaconda3\envs\tamamori\lib\site-packages\xlsxwriter\workbook.py:339: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %%
countries =["Australia", "India", "South East Asia", "Japan", "Rest of Asia Pacific", "South Korea", "People's Republic of China (mainland)", "Rest of Greater China", "Rest of Central & Eastern Europe",
                "Rest of Middle East", "France", "Germany", "UK", "Rest of Latin America", "Canada", "United States"]

# %%
type = ['ICE', 'BEV', 'PHEV', 'Others']

# %%
# 创建MultiIndex数据帧
cols1 = [['组1', '组1', '组2', '组2'], ['A', 'B', 'A', 'B']]
data = [[1, 2, 3, 4], [5, 6, 7, 8]]
index = ['第1行', '第2行']
df = pd.DataFrame(data, index=index, columns=cols1)

# 导出到Excel
df.to_excel('multi_header.xlsx', engine='openpyxl')

# %%
a = [(con, con, con, con) for con in countries]

# %%
a
# Out:
# [('Australia', 'Australia', 'Australia', 'Australia'),
#  ('India', 'India', 'India', 'India'),
#  ('South East Asia', 'South East Asia', 'South East Asia', 'South East Asia'),
#  ('Japan', 'Japan', 'Japan', 'Japan'),
#  ('Rest of Asia Pacific',
#   'Rest of Asia Pacific',
#   'Rest of Asia Pacific',
#   'Rest of Asia Pacific'),
#  ('South Korea', 'South Korea', 'South Korea', 'South Korea'),
#  ("People's Republic of China (mainland)",
#   "People's Republic of China (mainland)",
#   "People's Republic of China (mainland)",
#   "People's Republic of China (mainland)"),
#  ('Rest of Greater China',
#   'Rest of Greater China',
#   'Rest of Greater China',
#   'Rest of Greater China'),
#  ('Rest of Central & Eastern Europe',
#   'Rest of Central & Eastern Europe',
#   'Rest of Central & Eastern Europe',
#   'Rest of Central & Eastern Europe'),
#  ('Rest of Middle East',
#   'Rest of Middle East',
#   'Rest of Middle East',
#   'Rest of Middle East'),
#  ('France', 'France', 'France', 'France'),
#  ('Germany', 'Germany', 'Germany', 'Germany'),
#  ('UK', 'UK', 'UK', 'UK'),
#  ('Rest of Latin America',
#   'Rest of Latin America',
#   'Rest of Latin America',
#   'Rest of Latin America'),
#  ('Canada', 'Canada', 'Canada', 'Canada'),
#  ('United States', 'United States', 'United States', 'United States')]

# %%
b = [j for i in a for j in i]

# %%
c = [n for m in range(len(countries)) for n in type]

# %%
b
# Out:
# ['Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'India',
#  'India',
#  'India',
#  'India',
#  'South East Asia',
#  'South East Asia',
#  'South East Asia',
#  'South East Asia',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Rest of Asia Pacific',
#  'Rest of Asia Pacific',
#  'Rest of Asia Pacific',
#  'Rest of Asia Pacific',
#  'South Korea',
#  'South Korea',
#  'South Korea',
#  'South Korea',
#  "People's Republic of China (mainland)",
#  "People's Republic of China (mainland)",
#  "People's Republic of China (mainland)",
#  "People's Republic of China (mainland)",
#  'Rest of Greater China',
#  'Rest of Greater China',
#  'Rest of Greater China',
#  'Rest of Greater China',
#  'Rest of Central & Eastern Europe',
#  'Rest of Central & Eastern Europe',
#  'Rest of Central & Eastern Europe',
#  'Rest of Central & Eastern Europe',
#  'Rest of Middle East',
#  'Rest of Middle East',
#  'Rest of Middle East',
#  'Rest of Middle East',
#  'France',
#  'France',
#  'France',
#  'France',
#  'Germany',
#  'Germany',
#  'Germany',
#  'Germany',
#  'UK',
#  'UK',
#  'UK',
#  'UK',
#  'Rest of Latin America',
#  'Rest of Latin America',
#  'Rest of Latin America',
#  'Rest of Latin America',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'United States',
#  'United States',
#  'United States',
#  'United States']

# %%
c
# Out:
# ['ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others',
#  'ICE',
#  'BEV',
#  'PHEV',
#  'Others']

# %%
df1 = pd.DataFrame(columns=[b,c])

# %%
df1
# Out:
# Empty DataFrame
# Columns: [(Australia, ICE), (Australia, BEV), (Australia, PHEV), (Australia, Others), (India, ICE), (India, BEV), (India, PHEV), (India, Others), (South East Asia, ICE), (South East Asia, BEV), (South East Asia, PHEV), (South East Asia, Others), (Japan, ICE), (Japan, BEV), (Japan, PHEV), (Japan, Others), (Rest of Asia Pacific, ICE), (Rest of Asia Pacific, BEV), (Rest of Asia Pacific, PHEV), (Rest of Asia Pacific, Others), (South Korea, ICE), (South Korea, BEV), (South Korea, PHEV), (South Korea, Others), (People's Republic of China (mainland), ICE), (People's Republic of China (mainland), BEV), (People's Republic of China (mainland), PHEV), (People's Republic of China (mainland), Others), (Rest of Greater China, ICE), (Rest of Greater China, BEV), (Rest of Greater China, PHEV), (Rest of Greater China, Others), (Rest of Central & Eastern Europe, ICE), (Rest of Central & Eastern Europe, BEV), (Rest of Central & Eastern Europe, PHEV), (Rest of Central & Eastern Europe, Others), (Rest of Middle East, ICE), (Rest of Middle East, BEV), (Rest of Middle East, PHEV), (Rest of Middle East, Others), (France, ICE), (France, BEV), (France, PHEV), (France, Others), (Germany, ICE), (Germany, BEV), (Germany, PHEV), (Germany, Others), (UK, ICE), (UK, BEV), (UK, PHEV), (UK, Others), (Rest of Latin America, ICE), (Rest of Latin America, BEV), (Rest of Latin America, PHEV), (Rest of Latin America, Others), (Canada, ICE), (Canada, BEV), (Canada, PHEV), (Canada, Others), (United States, ICE), (United States, BEV), (United States, PHEV), (United States, Others)]
# Index: []
#
# [0 rows x 64 columns]

# %%
df1.to_excel("df1_test2.xlsx", engine='openpyxl')

# %%
# to_see
# Out:
#    (Australia, BEV) (Australia, ICE) (Australia, Others) (Australia, PHEV)  \
# 9               NaN              NaN                 NaN               NaN
# 2               NaN              NaN                 NaN               NaN
# 0               NaN              NaN                 NaN               NaN
# 4               NaN              NaN                 NaN               NaN
# 6               NaN              NaN                 NaN               NaN
# 8               NaN              NaN                 NaN               NaN
# 1               NaN              NaN                 NaN               NaN
# 3               NaN              NaN                 NaN               NaN
# 7               NaN              NaN                 NaN               NaN
# 16              NaN              NaN                 NaN               NaN
# 14              NaN              NaN                 NaN               NaN
# 15              NaN              NaN                 NaN               NaN
# 17              NaN              NaN                 NaN               NaN
# 5               NaN              NaN                 NaN               NaN
# 18              NaN              NaN                 NaN               NaN
# 10              NaN              NaN                 NaN               NaN
# 19              NaN              NaN                 NaN               NaN
# 12              NaN              NaN                 NaN               NaN
# 11              NaN              NaN                 NaN               NaN
# 13              NaN              NaN                 NaN               NaN
#
#    (Canada, BEV) (Canada, ICE) (Canada, Others) (Canada, PHEV) (France, BEV)  \
# 9            NaN           NaN              NaN            NaN           NaN
# 2            NaN           NaN              NaN            NaN           NaN
# 0            NaN           NaN              NaN            NaN           NaN
# 4            NaN           NaN              NaN            NaN           NaN
# 6            NaN           NaN              NaN            NaN           NaN
# 8            NaN           NaN              NaN            NaN           NaN
# 1            NaN           NaN              NaN            NaN           NaN
# 3            NaN           NaN              NaN            NaN           NaN
# 7            NaN           NaN              NaN            NaN           NaN
# 16           NaN           NaN              NaN            NaN           NaN
# 14           NaN           NaN              NaN            NaN           NaN
# 15           NaN           NaN              NaN            NaN           NaN
# 17           NaN           NaN              NaN            NaN           NaN
# 5            NaN           NaN              NaN            NaN           NaN
# 18           NaN           NaN              NaN            NaN           NaN
# 10           NaN           NaN              NaN            NaN           NaN
# 19           NaN           NaN              NaN            NaN           NaN
# 12           NaN           NaN              NaN            NaN           NaN
# 11           NaN           NaN              NaN            NaN           NaN
# 12  Volkswagen  Teramont/Atlas/Talagon/Tavendor  Volkswagen Group
# 11  Volkswagen                    Tiguan/Tayron  Volkswagen Group
# 13  Volkswagen                          Touareg  Volkswagen Group
#
#    Vehicle classification
# 9                     Car
# 2                     Car
# 0                     Car
# 4                     Car
# 6                     Car
# 8                     Car
# 1                     Car
# 3                     Car
# 7                     Car
# 16                    MPV
# 14                    MPV
# 15                    MPV
# 17                 Pickup
# 5           SUV/Crossover
# 18          SUV/Crossover
# 10          SUV/Crossover
# 19          SUV/Crossover
# 12          SUV/Crossover
# 11          SUV/Crossover
# 13          SUV/Crossover
#
# [20 rows x 68 columns]

# %%
too_see = pd.concat([vk_spec1, df1])

# %%
to_see.columns
# Out:
# Index([                               ('Australia', 'BEV'),
#                                       ('Australia', 'ICE'),
#                                    ('Australia', 'Others'),
#                                      ('Australia', 'PHEV'),
#                                          ('Canada', 'BEV'),
#                                          ('Canada', 'ICE'),
#                                       ('Canada', 'Others'),
#                                         ('Canada', 'PHEV'),
#                                          ('France', 'BEV'),
#                                          ('France', 'ICE'),
#                                       ('France', 'Others'),
#                                         ('France', 'PHEV'),
#                                         ('Germany', 'BEV'),
#                                         ('Germany', 'ICE'),
#                                      ('Germany', 'Others'),
#                                        ('Germany', 'PHEV'),
#                                           ('India', 'BEV'),
#                                           ('India', 'ICE'),
#                                        ('India', 'Others'),
#                                          ('India', 'PHEV'),
#                                           ('Japan', 'BEV'),
#                                           ('Japan', 'ICE'),
#                                        ('Japan', 'Others'),
#                                          ('Japan', 'PHEV'),
#           ('People's Republic of China (mainland)', 'BEV'),
#           ('People's Republic of China (mainland)', 'ICE'),
#        ('People's Republic of China (mainland)', 'Others'),
#          ('People's Republic of China (mainland)', 'PHEV'),
#                            ('Rest of Asia Pacific', 'BEV'),
#                            ('Rest of Asia Pacific', 'ICE'),
#                         ('Rest of Asia Pacific', 'Others'),
#                           ('Rest of Asia Pacific', 'PHEV'),
#                ('Rest of Central & Eastern Europe', 'BEV'),
#                ('Rest of Central & Eastern Europe', 'ICE'),
#             ('Rest of Central & Eastern Europe', 'Others'),
#               ('Rest of Central & Eastern Europe', 'PHEV'),
#                           ('Rest of Greater China', 'BEV'),
#                           ('Rest of Greater China', 'ICE'),
#                        ('Rest of Greater China', 'Others'),
#                          ('Rest of Greater China', 'PHEV'),
#                           ('Rest of Latin America', 'BEV'),
#                           ('Rest of Latin America', 'ICE'),
#                        ('Rest of Latin America', 'Others'),
#                          ('Rest of Latin America', 'PHEV'),
#                             ('Rest of Middle East', 'BEV'),
#                             ('Rest of Middle East', 'ICE'),
#                          ('Rest of Middle East', 'Others'),
#                            ('Rest of Middle East', 'PHEV'),
#                                 ('South East Asia', 'BEV'),
#                                 ('South East Asia', 'ICE'),
#                              ('South East Asia', 'Others'),
#                                ('South East Asia', 'PHEV'),
#                                     ('South Korea', 'BEV'),
#                                     ('South Korea', 'ICE'),
#                                  ('South Korea', 'Others'),
#                                    ('South Korea', 'PHEV'),
#                                              ('UK', 'BEV'),
#                                              ('UK', 'ICE'),
#                                           ('UK', 'Others'),
#                                             ('UK', 'PHEV'),
#                                   ('United States', 'BEV'),
#                                   ('United States', 'ICE'),
#                                ('United States', 'Others'),
#                                  ('United States', 'PHEV'),
#                                                    'Brand',
#                                             'Model family',
#                                                      'OEM',
#                                   'Vehicle classification'],
#       dtype='object')

# %%
vk_spec1.to_excel("vk_spec1.xlsx", index=False)

# %%
df1 = pd.read_excel("df1_test1.xlsx", header=[0,1])
df2 = pd.read_excel("vk_spec1.xlsx", header=[0,1])

# %%
df2.head()
# Out:
#                 OEM       Brand Vehicle classification         Model family
#    Volkswagen Group  Volkswagen                    Car            Arteon/CC
# 0  Volkswagen Group  Volkswagen                    Car  Bora/Lavida/Sagitar
# 1  Volkswagen Group  Volkswagen                    Car           Golf/Jetta
# 2  Volkswagen Group  Volkswagen                    Car                 ID.3
# 3  Volkswagen Group  Volkswagen                    Car       Passat/Magotan
# 4  Volkswagen Group  Volkswagen                    Car              Phideon

# %%
fin = pd.concat([df2, df1.drop([('Unnamed: 0_level_0', 'Unnamed: 0_level_1')], axis = 1)], axis = 1)
fin
# Out:
#                  OEM       Brand Vehicle classification  \
#     Volkswagen Group  Volkswagen                    Car
# 0   Volkswagen Group  Volkswagen                    Car
# 1   Volkswagen Group  Volkswagen                    Car
# 2   Volkswagen Group  Volkswagen                    Car
# 3   Volkswagen Group  Volkswagen                    Car
# 4   Volkswagen Group  Volkswagen                    Car
# 5   Volkswagen Group  Volkswagen                    Car
# 6   Volkswagen Group  Volkswagen                    Car
# 7   Volkswagen Group  Volkswagen                    Car
# 8   Volkswagen Group  Volkswagen                    MPV
# 9   Volkswagen Group  Volkswagen                    MPV
# 10  Volkswagen Group  Volkswagen                    MPV
# 11  Volkswagen Group  Volkswagen                 Pickup
# 12  Volkswagen Group  Volkswagen          SUV/Crossover
# 13  Volkswagen Group  Volkswagen          SUV/Crossover
# 14  Volkswagen Group  Volkswagen          SUV/Crossover
# 15  Volkswagen Group  Volkswagen          SUV/Crossover
# 16  Volkswagen Group  Volkswagen          SUV/Crossover
# 17  Volkswagen Group  Volkswagen          SUV/Crossover
# 18  Volkswagen Group  Volkswagen          SUV/Crossover
#
#                        Model family Australia                  India       \
#                           Arteon/CC       ICE  BEV PHEV Others   ICE  BEV
# 0               Bora/Lavida/Sagitar       NaN  NaN  NaN    NaN   NaN  NaN
# 1                        Golf/Jetta       NaN  NaN  NaN    NaN   NaN  NaN
# 2                              ID.3       NaN  NaN  NaN    NaN   NaN  NaN
# 3                    Passat/Magotan       NaN  NaN  NaN    NaN   NaN  NaN
# 4                           Phideon       NaN  NaN  NaN    NaN   NaN  NaN
# 5                              Polo       NaN  NaN  NaN    NaN   NaN  NaN
# 6              Virtus/Vento/Santana       NaN  NaN  NaN    NaN   NaN  NaN
# 7              Volkswage Car Others       NaN  NaN  NaN    NaN   NaN  NaN
# 8                           ID.Buzz       NaN  NaN  NaN    NaN   NaN  NaN
# 9                     Touran/Sharan       NaN  NaN  NaN    NaN   NaN  NaN
# 10                          Viloran       NaN  NaN  NaN    NaN   NaN  NaN
# 11                           Amarok       NaN  NaN  NaN    NaN   NaN  NaN
# 12                        ID.4/ID.5       NaN  NaN  NaN    NaN   NaN  NaN
# 13                             ID.6       NaN  NaN  NaN    NaN   NaN  NaN
# 14      T-Cross/Tacqua/Taigun/Taigo       NaN  NaN  NaN    NaN   NaN  NaN
# 15                       Taos/Tharu       NaN  NaN  NaN    NaN   NaN  NaN
# 16  Teramont/Atlas/Talagon/Tavendor       NaN  NaN  NaN    NaN   NaN  NaN
# 17                    Tiguan/Tayron       NaN  NaN  NaN    NaN   NaN  NaN
# 18                          Touareg       NaN  NaN  NaN    NaN   NaN  NaN
#
#     ... Rest of Latin America        Canada                  United States  \
#     ...                  PHEV Others    ICE  BEV PHEV Others           ICE
# 0   ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 1   ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 2   ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 3   ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 4   ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 5   ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 6   ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 7   ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 8   ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 9   ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 10  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 11  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 12  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 13  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 14  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 15  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 16  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 17  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 18  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
#
#
#     BEV PHEV Others
# 0   NaN  NaN    NaN
# 1   NaN  NaN    NaN
# 2   NaN  NaN    NaN
# 3   NaN  NaN    NaN
# 4   NaN  NaN    NaN
# 5   NaN  NaN    NaN
# 6   NaN  NaN    NaN
# 7   NaN  NaN    NaN
# 8   NaN  NaN    NaN
# 9   NaN  NaN    NaN
# 10  NaN  NaN    NaN
# 11  NaN  NaN    NaN
# 12  NaN  NaN    NaN
# 13  NaN  NaN    NaN
# 14  NaN  NaN    NaN
# 15  NaN  NaN    NaN
# 16  NaN  NaN    NaN
# 17  NaN  NaN    NaN
# 18  NaN  NaN    NaN
#
# [19 rows x 68 columns]

# %%
# fin.loc[0] = {
#   fin.columns[0] : fin.columns[0][1],
#   fin.columns[1] : fin.columns[1][1],
#   fin.columns[2] : fin.columns[2][1],
#   fin.columns[3] : fin.columns[3][1],
# }

# %%
# fin

# %%
# fin.columns = pd.MultiIndex.from_tuples(fin.set_axis(fin.columns.values, axis=1).rename(columns={
#    (fin.columns[0][0], fin.columns[0][1]): (fin.columns[0][0], ''),
#    (fin.columns[1][0], fin.columns[1][1]): (fin.columns[1][0], ''),
#    (fin.columns[2][0], fin.columns[2][1]): (fin.columns[2][0], ''),
#    (fin.columns[3][0], fin.columns[3][1]): (fin.columns[3][0], ''),

#   }))

# %%
# fin.columns[1][1]

# %%
l1 = [fin.columns[0][1], fin.columns[1][1], fin.columns[2][1], fin.columns[3][1]]

for _ in range(64):
  l1.append(np.NAN)
  
df = pd.DataFrame(np.insert(fin.values, 0, values= l1, axis=0))
df.head()
# Out:
#                  0           1    2                    3    4    5    6    7   \
# 0  Volkswagen Group  Volkswagen  Car            Arteon/CC  NaN  NaN  NaN  NaN
# 1  Volkswagen Group  Volkswagen  Car  Bora/Lavida/Sagitar  NaN  NaN  NaN  NaN
# 2  Volkswagen Group  Volkswagen  Car           Golf/Jetta  NaN  NaN  NaN  NaN
# 3  Volkswagen Group  Volkswagen  Car                 ID.3  NaN  NaN  NaN  NaN
# 4  Volkswagen Group  Volkswagen  Car       Passat/Magotan  NaN  NaN  NaN  NaN
#
#     8    9   ...   58   59   60   61   62   63   64   65   66   67
# 0  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 68 columns]

# %%
fin.columns = pd.MultiIndex.from_tuples(fin.set_axis(fin.columns.values, axis=1).rename(columns={
   (fin.columns[0][0], fin.columns[0][1]): (fin.columns[0][0], ''),
   (fin.columns[1][0], fin.columns[1][1]): (fin.columns[1][0], ''),
   (fin.columns[2][0], fin.columns[2][1]): (fin.columns[2][0], ''),
   (fin.columns[3][0], fin.columns[3][1]): (fin.columns[3][0], ''),

  }))

# %%
df.columns = fin.columns
df.head()
# Out:
#                 OEM       Brand Vehicle classification         Model family  \
#
# 0  Volkswagen Group  Volkswagen                    Car            Arteon/CC
# 1  Volkswagen Group  Volkswagen                    Car  Bora/Lavida/Sagitar
# 2  Volkswagen Group  Volkswagen                    Car           Golf/Jetta
# 3  Volkswagen Group  Volkswagen                    Car                 ID.3
# 4  Volkswagen Group  Volkswagen                    Car       Passat/Magotan
#
#   Australia                  India       ... Rest of Latin America         \
#         ICE  BEV PHEV Others   ICE  BEV  ...                  PHEV Others
# 0       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 1       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 2       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 3       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 4       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
#
#   Canada                  United States
#      ICE  BEV PHEV Others           ICE  BEV PHEV Others
# 0    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 1    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 2    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 3    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 4    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
#
# [5 rows x 68 columns]

# %%
df.to_excel("df_sample.xlsx")

# %%
df.columns.levels[0]
# Out:
# Index(['Australia', 'Brand', 'Canada', 'France', 'Germany', 'India', 'Japan',
#        'Model family', 'OEM', 'People's Republic of China (mainland)',
#        'Rest of Asia Pacific', 'Rest of Central & Eastern Europe',
#        'Rest of Greater China', 'Rest of Latin America', 'Rest of Middle East',
#        'South East Asia', 'South Korea', 'UK', 'United States',
#        'Vehicle classification'],
#       dtype='object')

# %%
all_row2 = ['ALL', 'ALL', 'ALL', 'ALL', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others', 'ICE', 'BEV', 'PHEV', 'Others']
ALL_df2 = pd.DataFrame(data = [all_row2], columns= df.columns)

# for c in countries:
#     for t in ['ICE', 'BEV', 'PHEV', 'Others']:
#         ALL_df2[c] = c
#         ALL_df[t] = t

ALL_df2
# Out:
#    OEM Brand Vehicle classification Model family Australia                     \
#                                                        ICE  BEV  PHEV  Others
# 0  ALL   ALL                    ALL          ALL       ICE  BEV  PHEV  Others
#
#   India       ... Rest of Latin America         Canada                     \
#     ICE  BEV  ...                  PHEV  Others    ICE  BEV  PHEV  Others
# 0   ICE  BEV  ...                  PHEV  Others    ICE  BEV  PHEV  Others
#
#   United States
#             ICE  BEV  PHEV  Others
# 0           ICE  BEV  PHEV  Others
#
# [1 rows x 68 columns]

# %%
nan_row2 = pd.DataFrame([[np.NAN]*68], columns = ALL_df2.columns)

# %%
df.columns[2]
# Out:
# ('Vehicle classification', '')

# %%
gp4 = list(df.groupby(df.columns[2]))
row_list4 = []

for ind, row in gp4:
    print(row)
    res4 = pd.concat([ALL_df2, row, nan_row2], axis=0)
    row_list4.append(res4)
# Out:
#                 OEM       Brand Vehicle classification          Model family  \
#
# 0  Volkswagen Group  Volkswagen                    Car             Arteon/CC
# 1  Volkswagen Group  Volkswagen                    Car   Bora/Lavida/Sagitar
# 2  Volkswagen Group  Volkswagen                    Car            Golf/Jetta
# 3  Volkswagen Group  Volkswagen                    Car                  ID.3
# 4  Volkswagen Group  Volkswagen                    Car        Passat/Magotan
# 5  Volkswagen Group  Volkswagen                    Car               Phideon
# 6  Volkswagen Group  Volkswagen                    Car                  Polo
# 7  Volkswagen Group  Volkswagen                    Car  Virtus/Vento/Santana
# 8  Volkswagen Group  Volkswagen                    Car  Volkswage Car Others
#
#   Australia                  India       ... Rest of Latin America         \
#         ICE  BEV PHEV Others   ICE  BEV  ...                  PHEV Others
# 0       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 1       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 2       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 3       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 4       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 5       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 6       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 7       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 8       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
#
#   Canada                  United States
#      ICE  BEV PHEV Others           ICE  BEV PHEV Others
# 0    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 1    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 2    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 3    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 4    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 5    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 6    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 7    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 8    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
#
# [9 rows x 68 columns]
#                  OEM       Brand Vehicle classification   Model family  \
#
# 9   Volkswagen Group  Volkswagen                    MPV        ID.Buzz
# 10  Volkswagen Group  Volkswagen                    MPV  Touran/Sharan
# 11  Volkswagen Group  Volkswagen                    MPV        Viloran
#
#    Australia                  India       ... Rest of Latin America         \
#          ICE  BEV PHEV Others   ICE  BEV  ...                  PHEV Others
# 9        NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 10       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
# 11       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
#
#    Canada                  United States
#       ICE  BEV PHEV Others           ICE  BEV PHEV Others
# 9     NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 10    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
# 11    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
#
# [3 rows x 68 columns]
#                  OEM       Brand Vehicle classification Model family  \
#
# 12  Volkswagen Group  Volkswagen                 Pickup       Amarok
#
#    Australia                  India       ... Rest of Latin America         \
#          ICE  BEV PHEV Others   ICE  BEV  ...                  PHEV Others
# 12       NaN  NaN  NaN    NaN   NaN  NaN  ...                   NaN    NaN
#
#    Canada                  United States
#       ICE  BEV PHEV Others           ICE  BEV PHEV Others
# 12    NaN  NaN  NaN    NaN           NaN  NaN  NaN    NaN
#
# [1 rows x 68 columns]
#                  OEM       Brand Vehicle classification  \
#
# 13  Volkswagen Group  Volkswagen          SUV/Crossover
# 14  Volkswagen Group  Volkswagen          SUV/Crossover
# 15  Volkswagen Group  Volkswagen          SUV/Crossover
# 16  Volkswagen Group  Volkswagen          SUV/Crossover
# 17  Volkswagen Group  Volkswagen          SUV/Crossover
# 18  Volkswagen Group  Volkswagen          SUV/Crossover
# 19  Volkswagen Group  Volkswagen          SUV/Crossover
#
#                        Model family Australia                  India       \
#                                           ICE  BEV PHEV Others   ICE  BEV
# 13                        ID.4/ID.5       NaN  NaN  NaN    NaN   NaN  NaN
# 14                             ID.6       NaN  NaN  NaN    NaN   NaN  NaN
# 15      T-Cross/Tacqua/Taigun/Taigo       NaN  NaN  NaN    NaN   NaN  NaN
# 16                       Taos/Tharu       NaN  NaN  NaN    NaN   NaN  NaN
# 17  Teramont/Atlas/Talagon/Tavendor       NaN  NaN  NaN    NaN   NaN  NaN
# 18                    Tiguan/Tayron       NaN  NaN  NaN    NaN   NaN  NaN
# 19                          Touareg       NaN  NaN  NaN    NaN   NaN  NaN
#
#     ... Rest of Latin America        Canada                  United States  \
#     ...                  PHEV Others    ICE  BEV PHEV Others           ICE
# 13  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 14  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 15  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 16  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 17  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 18  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
# 19  ...                   NaN    NaN    NaN  NaN  NaN    NaN           NaN
#
#
#     BEV PHEV Others
# 13  NaN  NaN    NaN
# 14  NaN  NaN    NaN
# 15  NaN  NaN    NaN
# 16  NaN  NaN    NaN
# 17  NaN  NaN    NaN
# 18  NaN  NaN    NaN
# 19  NaN  NaN    NaN
#
# [7 rows x 68 columns]

# %%
fin4 = pd.concat(row_list4).reset_index(drop=True)

# %%
fin4
# Out:
#                  OEM       Brand Vehicle classification  \
#
# 0                ALL         ALL                    ALL
# 1   Volkswagen Group  Volkswagen                    Car
# 2   Volkswagen Group  Volkswagen                    Car
# 3   Volkswagen Group  Volkswagen                    Car
# 4   Volkswagen Group  Volkswagen                    Car
# 5   Volkswagen Group  Volkswagen                    Car
# 6   Volkswagen Group  Volkswagen                    Car
# 7   Volkswagen Group  Volkswagen                    Car
# 8   Volkswagen Group  Volkswagen                    Car
# 9   Volkswagen Group  Volkswagen                    Car
# 10               NaN         NaN                    NaN
# 11               ALL         ALL                    ALL
# 12  Volkswagen Group  Volkswagen                    MPV
# 13  Volkswagen Group  Volkswagen                    MPV
# 14  Volkswagen Group  Volkswagen                    MPV
# 15               NaN         NaN                    NaN
# 16               ALL         ALL                    ALL
# 17  Volkswagen Group  Volkswagen                 Pickup
# 18               NaN         NaN                    NaN
# 19               ALL         ALL                    ALL
# 20  Volkswagen Group  Volkswagen          SUV/Crossover
# 21  Volkswagen Group  Volkswagen          SUV/Crossover
# 22  Volkswagen Group  Volkswagen          SUV/Crossover
# 23  Volkswagen Group  Volkswagen          SUV/Crossover
# 24  Volkswagen Group  Volkswagen          SUV/Crossover
# 25  Volkswagen Group  Volkswagen          SUV/Crossover
# 26  Volkswagen Group  Volkswagen          SUV/Crossover
# 27               NaN         NaN                    NaN
#
#                        Model family Australia                    India       \
#                                           ICE  BEV  PHEV  Others   ICE  BEV
# 0                               ALL       ICE  BEV  PHEV  Others   ICE  BEV
# 1                         Arteon/CC       NaN  NaN   NaN     NaN   NaN  NaN
# 2               Bora/Lavida/Sagitar       NaN  NaN   NaN     NaN   NaN  NaN
# 3                        Golf/Jetta       NaN  NaN   NaN     NaN   NaN  NaN
# 4                              ID.3       NaN  NaN   NaN     NaN   NaN  NaN
# 5                    Passat/Magotan       NaN  NaN   NaN     NaN   NaN  NaN
# 6                           Phideon       NaN  NaN   NaN     NaN   NaN  NaN
# 26  NaN   NaN     NaN
# 27  NaN   NaN     NaN
#
# [28 rows x 68 columns]

# %%
# fin4.to_excel("fin4_to_see.xlsx")

# %%
fin4 = fin4.rename(columns={fin4.columns[0][1]:'ALL'})

# %%
fin4
# Out:
#                  OEM       Brand Vehicle classification  \
#                  ALL         ALL                    ALL
# 0                ALL         ALL                    ALL
# 1   Volkswagen Group  Volkswagen                    Car
# 2   Volkswagen Group  Volkswagen                    Car
# 3   Volkswagen Group  Volkswagen                    Car
# 4   Volkswagen Group  Volkswagen                    Car
# 5   Volkswagen Group  Volkswagen                    Car
# 6   Volkswagen Group  Volkswagen                    Car
# 7   Volkswagen Group  Volkswagen                    Car
# 8   Volkswagen Group  Volkswagen                    Car
# 9   Volkswagen Group  Volkswagen                    Car
# 10               NaN         NaN                    NaN
# 11               ALL         ALL                    ALL
# 12  Volkswagen Group  Volkswagen                    MPV
# 13  Volkswagen Group  Volkswagen                    MPV
# 14  Volkswagen Group  Volkswagen                    MPV
# 15               NaN         NaN                    NaN
# 16               ALL         ALL                    ALL
# 17  Volkswagen Group  Volkswagen                 Pickup
# 18               NaN         NaN                    NaN
# 19               ALL         ALL                    ALL
# 20  Volkswagen Group  Volkswagen          SUV/Crossover
# 21  Volkswagen Group  Volkswagen          SUV/Crossover
# 22  Volkswagen Group  Volkswagen          SUV/Crossover
# 23  Volkswagen Group  Volkswagen          SUV/Crossover
# 24  Volkswagen Group  Volkswagen          SUV/Crossover
# 25  Volkswagen Group  Volkswagen          SUV/Crossover
# 26  Volkswagen Group  Volkswagen          SUV/Crossover
# 27               NaN         NaN                    NaN
#
#                        Model family Australia                    India       \
#                                 ALL       ICE  BEV  PHEV  Others   ICE  BEV
# 0                               ALL       ICE  BEV  PHEV  Others   ICE  BEV
# 1                         Arteon/CC       NaN  NaN   NaN     NaN   NaN  NaN
# 2               Bora/Lavida/Sagitar       NaN  NaN   NaN     NaN   NaN  NaN
# 3                        Golf/Jetta       NaN  NaN   NaN     NaN   NaN  NaN
# 4                              ID.3       NaN  NaN   NaN     NaN   NaN  NaN
# 5                    Passat/Magotan       NaN  NaN   NaN     NaN   NaN  NaN
# 6                           Phideon       NaN  NaN   NaN     NaN   NaN  NaN
# 7                              Polo       NaN  NaN   NaN     NaN   NaN  NaN
# 8              Virtus/Vento/Santana       NaN  NaN   NaN     NaN   NaN  NaN
# 9              Volkswage Car Others       NaN  NaN   NaN     NaN   NaN  NaN
# 10                              NaN       NaN  NaN   NaN     NaN   NaN  NaN
# 11                              ALL       ICE  BEV  PHEV  Others   ICE  BEV
# 12                          ID.Buzz       NaN  NaN   NaN     NaN   NaN  NaN
# 13                    Touran/Sharan       NaN  NaN   NaN     NaN   NaN  NaN
# 14                          Viloran       NaN  NaN   NaN     NaN   NaN  NaN
# 15                              NaN       NaN  NaN   NaN     NaN   NaN  NaN
# 16                              ALL       ICE  BEV  PHEV  Others   ICE  BEV
# 17                           Amarok       NaN  NaN   NaN     NaN   NaN  NaN
# 18                              NaN       NaN  NaN   NaN     NaN   NaN  NaN
# 19                              ALL       ICE  BEV  PHEV  Others   ICE  BEV
# 20                        ID.4/ID.5       NaN  NaN   NaN     NaN   NaN  NaN
# 21                             ID.6       NaN  NaN   NaN     NaN   NaN  NaN
# 22      T-Cross/Tacqua/Taigun/Taigo       NaN  NaN   NaN     NaN   NaN  NaN
# 23                       Taos/Tharu       NaN  NaN   NaN     NaN   NaN  NaN
# 24  Teramont/Atlas/Talagon/Tavendor       NaN  NaN   NaN     NaN   NaN  NaN
# 25                    Tiguan/Tayron       NaN  NaN   NaN     NaN   NaN  NaN
# 26                          Touareg       NaN  NaN   NaN     NaN   NaN  NaN
# 27                              NaN       NaN  NaN   NaN     NaN   NaN  NaN
#
#     ... Rest of Latin America         Canada                    United States  \
#     ...                  PHEV  Others    ICE  BEV  PHEV  Others           ICE
# 0   ...                  PHEV  Others    ICE  BEV  PHEV  Others           ICE
# 1   ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 2   ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 3   ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 4   ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 5   ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 6   ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 7   ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 8   ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 9   ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 10  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 11  ...                  PHEV  Others    ICE  BEV  PHEV  Others           ICE
# 12  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 13  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 14  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 15  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 16  ...                  PHEV  Others    ICE  BEV  PHEV  Others           ICE
# 17  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 18  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 19  ...                  PHEV  Others    ICE  BEV  PHEV  Others           ICE
# 20  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 21  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 22  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 23  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 24  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 25  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 26  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
# 27  ...                   NaN     NaN    NaN  NaN   NaN     NaN           NaN
#
#
#     BEV  PHEV  Others
# 0   BEV  PHEV  Others
# 1   NaN   NaN     NaN
# 2   NaN   NaN     NaN
# 3   NaN   NaN     NaN
# 4   NaN   NaN     NaN
# 5   NaN   NaN     NaN
# 6   NaN   NaN     NaN
# 7   NaN   NaN     NaN
# 8   NaN   NaN     NaN
# 9   NaN   NaN     NaN
# 10  NaN   NaN     NaN
# 11  BEV  PHEV  Others
# 12  NaN   NaN     NaN
# 13  NaN   NaN     NaN
# 14  NaN   NaN     NaN
# 15  NaN   NaN     NaN
# 16  BEV  PHEV  Others
# 17  NaN   NaN     NaN
# 18  NaN   NaN     NaN
# 19  BEV  PHEV  Others
# 20  NaN   NaN     NaN
# 21  NaN   NaN     NaN
# 22  NaN   NaN     NaN
# 23  NaN   NaN     NaN
# 24  NaN   NaN     NaN
# 25  NaN   NaN     NaN
# 26  NaN   NaN     NaN
# 27  NaN   NaN     NaN
#
# [28 rows x 68 columns]

# %%
fin4.shape
# Out:
# (28, 68)

# %%
with pd.ExcelWriter('12345.xlsx', engine='xlsxwriter') as writer:
    fin4.to_excel(writer, sheet_name='Sheet1')
    formatObje = writer.book.add_format({'num_format': '0.00%'})
    writer.book.sheetnames['Sheet1'].set_column('F:BQ', cell_format=formatObje)
    workbook = writer.book
    worksheet = writer.sheets['Sheet1']
    
    worksheet.write_array_formula(4,5,len(fin4)+1, 5, '{=1-SUM(G:I)}')

writer.close()
# Out:
# C:\Users\DanHan\anaconda3\envs\tamamori\lib\site-packages\xlsxwriter\workbook.py:339: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")
